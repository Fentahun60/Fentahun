# %% [markdown]
# <a href="https://colab.research.google.com/github/Fentahun60/Fentahun/blob/main/AFter_comments_Zambia_CC_Sept_2026.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')

import pandas as pd

# Path to your .dta file
file_path = '/content/drive/MyDrive/zambia_CC_BC.dta'

# Read the .dta file into a pandas DataFrame
try:
    df = pd.read_stata(file_path)
    print("File imported successfully! First 5 rows:")
    display(df.head())
except FileNotFoundError:
    print(f"Error: The file '{file_path}' was not found. Please ensure the path is correct and Google Drive is mounted.")
except Exception as e:
    print(f"An error occurred while reading the file: {e}")
# Out:
# Mounted at /content/drive
# File imported successfully! First 5 rows:
#   v000  v001    v005  v007  v012   v025       v106    v151 v152  \
# 0  ZM8     1  748300  2024    42  urban    primary    male   44
# 1  ZM8     1  748300  2024    42  urban     higher  female   41
# 2  ZM8     1  748300  2024    24  urban    primary  female   24
# 3  ZM8     1  748300  2024    22  urban  secondary    male   26
# 4  ZM8     1  748300  2024    32  urban    primary  female   32
#
#                    v157  ... v481 v484a v484b  \
# 0            not at all  ...   no    no    no
# 1  at least once a week  ...  yes   yes   yes
# 2  at least once a week  ...   no    no    no
# 3            not at all  ...   no    no    no
# 4  at least once a week  ...   no    no   yes
#
#                                   v501 v525 v763a v763b v763c v781 v836
# 0                              married   22    no    no    no  yes  2.0
# 1                              married   17    no    no    no  yes  3.0
# ...

# %%
# Assuming your dataframe is df

rename_dict = {
    "v012": "respondent_age",
    "v025": "residence_type",
    "v106": "highest_edu_level",
    "v151": "sex_of_household_head",
    "v152": "age_of_household_head",
    "v157": "freq_read_newspaper",
    "v158": "freq_listen_radio",
    "v159": "freq_watch_tv",
    "v169a": "owns_mobile_phone",
    "v190": "wealth_index",
    "v312": "current_contraceptive_method",
    "v394": "visited_health_facility_12mo",
    "v463a": "smokes_cigarettes",
    "v467b": "permission_to_medical_Vist",
    "v467c": "money_needed_for_medical_vist",
    "v467d": "distance_to_health_facility",
    "v467e": "transport_for_medical_visit",
    "v467k": "waiting_time_concern_at_HF",
    "v481": "covered_by_health_insurance",
    "v484a": "breast_exam_by_provider",
    "v484b": "cervical_cancer_tested",
    "v501": "marital_status",
    "v525": "age_at_first_sex",
    "v763a": "STI_last_12mo",
    "v763b": "genital_sore_last_12mo",
    "v763c": "genital_discharge_last_12mo",
    "v781": "ever_tested_hiv",
    "v836": "total_lifetime_sex_partners"
}

# Apply renaming
df = df.rename(columns=rename_dict)

df.head()
# Out:
#   v000  v001    v005  v007  respondent_age residence_type highest_edu_level  \
# 0  ZM8     1  748300  2024              42          urban           primary
# 1  ZM8     1  748300  2024              42          urban            higher
# 2  ZM8     1  748300  2024              24          urban           primary
# 3  ZM8     1  748300  2024              22          urban         secondary
# 4  ZM8     1  748300  2024              32          urban           primary
#
#   sex_of_household_head age_of_household_head   freq_read_newspaper  ...  \
# 0                  male                    44            not at all  ...
# 1                female                    41  at least once a week  ...
# 2                female                    24  at least once a week  ...
# 3                  male                    26            not at all  ...
# 4                female                    32  at least once a week  ...
#
# ...

# %%
df.columns
# Out:
# Index(['v000', 'v001', 'v005', 'v007', 'respondent_age', 'residence_type',
#        'highest_edu_level', 'sex_of_household_head', 'age_of_household_head',
#        'freq_read_newspaper', 'freq_listen_radio', 'freq_watch_tv',
#        'owns_mobile_phone', 'wealth_index', 'current_contraceptive_method',
#        'visited_health_facility_12mo', 'smokes_cigarettes',
#        'permission_to_medical_Vist', 'money_needed_for_medical_vist',
#        'distance_to_health_facility', 'transport_for_medical_visit',
#        'waiting_time_concern_at_HF', 'covered_by_health_insurance',
#        'breast_exam_by_provider', 'cervical_cancer_tested', 'marital_status',
#        'age_at_first_sex', 'STI_last_12mo', 'genital_sore_last_12mo',
#        'genital_discharge_last_12mo', 'ever_tested_hiv',
#        'total_lifetime_sex_partners'],
#       dtype='object')

# %%
df["freq_listen_radio"] = df["freq_listen_radio"].replace({
    "not at all": "No",
    "less than once a week": "No",
    "at least once a week": "Yes",
    "almost every day": "Yes"})
# Out:
# /tmp/ipykernel_2464/2432297828.py:1: FutureWarning: The behavior of Series.replace (and DataFrame.replace) with CategoricalDtype is deprecated. In a future version, replace will only be used for cases that preserve the categories. To change the categories, use ser.cat.rename_categories instead.
#   df["freq_listen_radio"] = df["freq_listen_radio"].replace({

# %%
df["freq_watch_tv"] = df["freq_watch_tv"].replace({
    "not at all": "No",
    "less than once a week": "No",
    "at least once a week": "Yes",
    "almost every day": "Yes"})
# Out:
# /tmp/ipykernel_2464/3206452986.py:1: FutureWarning: The behavior of Series.replace (and DataFrame.replace) with CategoricalDtype is deprecated. In a future version, replace will only be used for cases that preserve the categories. To change the categories, use ser.cat.rename_categories instead.
#   df["freq_watch_tv"] = df["freq_watch_tv"].replace({

# %%
df.shape
# Out:
# (13951, 32)

# %%
df["current_contraceptive_method"] = df["current_contraceptive_method"].replace({

    # Hormonal
    "pill": "Hormonal",
    "injections": "Hormonal",
    "implants/norplant": "Hormonal",
    "emergency contraception": "Hormonal",
    "lactational amenorrhea (lam)": "Hormonal",

    # Non-hormonal
    "not using": "Non-Hormonal",
    "iud": "Non-Hormonal",
    "male condom": "Non-Hormonal",
    "female condom": "Non-Hormonal",
    "female sterilization": "Non-Hormonal",
    "periodic abstinence": "Non-Hormonal",
    "withdrawal": "Non-Hormonal",
    "other traditional": "Non-Hormonal",
    "other modern method": "Non-Hormonal",
    "standard days method (sdm)": "Non-Hormonal"
})
# Out:
# /tmp/ipykernel_2464/214665719.py:1: FutureWarning: The behavior of Series.replace (and DataFrame.replace) with CategoricalDtype is deprecated. In a future version, replace will only be used for cases that preserve the categories. To change the categories, use ser.cat.rename_categories instead.
#   df["current_contraceptive_method"] = df["current_contraceptive_method"].replace({

# %%
import matplotlib.pyplot as plt

plt.boxplot(df['respondent_age'])
plt.title("Boxplot of Respondent Age")
plt.show()

# %%
# Min-Max Normalization
df['respondent_age'] = (df['respondent_age'] - df['respondent_age'].min()) / \
                                  (df['respondent_age'].max() - df['respondent_age'].min())

# Display first few rows to check
print(df[['respondent_age', 'respondent_age']].head())
# Out:
#    respondent_age  respondent_age
# 0        0.794118        0.794118
# 1        0.794118        0.794118
# 2        0.264706        0.264706
# 3        0.205882        0.205882
# 4        0.500000        0.500000

# %%
import pandas as pd
import numpy as np

# Example: your dataframe is df and the column is 'age_at_first_sex'

def recategorize_age(x):
    # Handle non-numeric values first
    if pd.isna(x):
        return np.nan
    if isinstance(x, str) and x.lower() == "not had sex":
        return "not had sex"

    # Convert to numeric if it's a string number
    try:
        x = float(x)
    except:
        return np.nan

    # Categorize
    if x < 15:
        return "<15"
    elif 15 <= x <= 17:
        return "15-17"
    elif 18 <= x <= 19:
        return "18-19"
    elif x >= 20:
        return ">20"
    else:
        return np.nan

# Apply to dataframe
df["age_at_first_sex"] = df["age_at_first_sex"].apply(recategorize_age)

# View result
df["age_at_first_sex"].value_counts(dropna=False)
# Out:
# age_at_first_sex
# 15-17          6497
# <15            2392
# 18-19          2105
# not had sex    1707
# >20            1250
# Name: count, dtype: int64

# %%
df['total_lifetime_sex_partners'].dtype
df['total_lifetime_sex_partners'].unique()  # see if there are unexpected strings
# Out:
# [2.0, 3.0, 5.0, 4.0, NaN, ..., 25.0, 35.0, 27.0, 50.0, 29.0]
# Length: 29
# Categories (28, object): [1.0 < 2.0 < 3.0 < 4.0 ... 47.0 < 50.0 < '95+' < 'don't know']

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Replace specific strings with 0
df['total_lifetime_sex_partners'] = df['total_lifetime_sex_partners'].replace({
    '95+': 0,
    "don't know": 0
})

# Convert the column to numeric (coerce any other invalid entries to 0)
df['total_lifetime_sex_partners'] = pd.to_numeric(
    df['total_lifetime_sex_partners'], errors='coerce'
).fillna(0)

# Plot the boxplot
plt.figure(figsize=(8,6))
plt.boxplot(df['total_lifetime_sex_partners'])
plt.title("Boxplot of Total Lifetime Sexual Partners")
plt.ylabel("Number of Partners")
plt.show()
# Out:
# /tmp/ipykernel_2464/1611095577.py:5: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df['total_lifetime_sex_partners'] = df['total_lifetime_sex_partners'].replace({
# /tmp/ipykernel_2464/1611095577.py:5: FutureWarning: The behavior of Series.replace (and DataFrame.replace) with CategoricalDtype is deprecated. In a future version, replace will only be used for cases that preserve the categories. To change the categories, use ser.cat.rename_categories instead.
#   df['total_lifetime_sex_partners'] = df['total_lifetime_sex_partners'].replace({

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# Replace specific strings with 0
df['total_lifetime_sex_partners'] = df['total_lifetime_sex_partners'].replace({
    '95+': 0,
    "don't know": 0
})

# Convert the column to numeric (coerce any other invalid entries to 0)
df['total_lifetime_sex_partners'] = pd.to_numeric(
    df['total_lifetime_sex_partners'], errors='coerce'
).fillna(0)

# Apply log transformation (log(x + 1) to handle zeros)
df['total_lifetime_sex_partners'] = np.log1p(df['total_lifetime_sex_partners'])

# Plot the boxplot of log-transformed data
plt.figure(figsize=(8,6))
plt.boxplot(df['total_lifetime_sex_partners'])
plt.title("Boxplot of Log-Transformed Total Lifetime Sexual Partners")
plt.ylabel("Log(Number of Partners + 1)")
plt.show()

# %%
missing_percentages = df.isnull().sum() / len(df) * 100
missing_percentages_df = pd.DataFrame({"Missing Percentage": missing_percentages})

print("Percentage of missing values for each variable:")
print(missing_percentages_df)
# Out:
# Percentage of missing values for each variable:
#                                Missing Percentage
# v000                                          0.0
# v001                                          0.0
# v005                                          0.0
# v007                                          0.0
# respondent_age                                0.0
# residence_type                                0.0
# highest_edu_level                             0.0
# sex_of_household_head                         0.0
# age_of_household_head                         0.0
# freq_read_newspaper                           0.0
# freq_listen_radio                             0.0
# freq_watch_tv                                 0.0
# owns_mobile_phone                             0.0
# wealth_index                                  0.0
# current_contraceptive_method                  0.0
# visited_health_facility_12mo                  0.0
# smokes_cigarettes                             0.0
# ...

# %%
df.head()
# Out:
#   v000  v001    v005  v007  respondent_age residence_type highest_edu_level  \
# 0  ZM8     1  748300  2024        0.794118          urban           primary
# 1  ZM8     1  748300  2024        0.794118          urban            higher
# 2  ZM8     1  748300  2024        0.264706          urban           primary
# 3  ZM8     1  748300  2024        0.205882          urban         secondary
# 4  ZM8     1  748300  2024        0.500000          urban           primary
#
#   sex_of_household_head age_of_household_head   freq_read_newspaper  ...  \
# 0                  male                    44            not at all  ...
# 1                female                    41  at least once a week  ...
# 2                female                    24  at least once a week  ...
# 3                  male                    26            not at all  ...
# 4                female                    32  at least once a week  ...
#
# ...

# %%
df = df.drop('freq_read_newspaper', axis=1)

# %%
df.columns
# Out:
# Index(['v000', 'v001', 'v005', 'v007', 'respondent_age', 'residence_type',
#        'highest_edu_level', 'sex_of_household_head', 'age_of_household_head',
#        'freq_listen_radio', 'freq_watch_tv', 'owns_mobile_phone',
#        'wealth_index', 'current_contraceptive_method',
#        'visited_health_facility_12mo', 'smokes_cigarettes',
#        'permission_to_medical_Vist', 'money_needed_for_medical_vist',
#        'distance_to_health_facility', 'transport_for_medical_visit',
#        'waiting_time_concern_at_HF', 'covered_by_health_insurance',
#        'breast_exam_by_provider', 'cervical_cancer_tested', 'marital_status',
#        'age_at_first_sex', 'STI_last_12mo', 'genital_sore_last_12mo',
#        'genital_discharge_last_12mo', 'ever_tested_hiv',
#        'total_lifetime_sex_partners'],
#       dtype='object')

# %%
df.head()
# Out:
#   v000  v001    v005  v007  respondent_age residence_type highest_edu_level  \
# 0  ZM8     1  748300  2024        0.794118          urban           primary
# 1  ZM8     1  748300  2024        0.794118          urban            higher
# 2  ZM8     1  748300  2024        0.264706          urban           primary
# 3  ZM8     1  748300  2024        0.205882          urban         secondary
# 4  ZM8     1  748300  2024        0.500000          urban           primary
#
#   sex_of_household_head age_of_household_head freq_listen_radio  ...  \
# 0                  male                    44                No  ...
# 1                female                    41               Yes  ...
# 2                female                    24                No  ...
# 3                  male                    26                No  ...
# 4                female                    32                No  ...
#
#   covered_by_health_insurance breast_exam_by_provider cervical_cancer_tested  \
# ...

# %%
import matplotlib.pyplot as plt
import pandas as pd

# Convert to numeric, invalid entries become NaN
df['age_of_household_head'] = pd.to_numeric(df['age_of_household_head'], errors='coerce')

# Drop NaN values for plotting
ages = df['age_of_household_head'].dropna()

# Plot boxplot
plt.boxplot(ages)
plt.title("Boxplot of Age of Household Head")
plt.ylabel("Age")
plt.show()

# %%
import matplotlib.pyplot as plt
import pandas as pd

# Convert to numeric, invalid entries become NaN
df['age_of_household_head'] = pd.to_numeric(df['age_of_household_head'], errors='coerce')

# Drop NaN values temporarily to compute min and max
ages = df['age_of_household_head'].dropna()

# Min-Max normalization
ages_normalized = (ages - ages.min()) / (ages.max() - ages.min())

# Replace the existing column with normalized values
df.loc[ages_normalized.index, 'age_of_household_head'] = ages_normalized

# Plot boxplot of normalized values
plt.boxplot(df['age_of_household_head'].dropna())
plt.title("Boxplot of Normalized Age of Household Head (Min-Max)")
plt.ylabel("Normalized Age")
plt.show()

# %%
df.head()
# Out:
#   v000  v001    v005  v007  respondent_age residence_type highest_edu_level  \
# 0  ZM8     1  748300  2024        0.794118          urban           primary
# 1  ZM8     1  748300  2024        0.794118          urban            higher
# 2  ZM8     1  748300  2024        0.264706          urban           primary
# 3  ZM8     1  748300  2024        0.205882          urban         secondary
# 4  ZM8     1  748300  2024        0.500000          urban           primary
#
#   sex_of_household_head  age_of_household_head freq_listen_radio  ...  \
# 0                  male                 0.3625                No  ...
# 1                female                 0.3250               Yes  ...
# 2                female                 0.1125                No  ...
# 3                  male                 0.1375                No  ...
# 4                female                 0.2125                No  ...
#
#   covered_by_health_insurance breast_exam_by_provider cervical_cancer_tested  \
# ...

# %%
print(df['marital_status'].value_counts(dropna=False))
# Out:
# marital_status
# married                                7358
# never in union                         4628
# divorced                               1050
# no longer living together/separated     453
# widowed                                 363
# living with partner                      99
# Name: count, dtype: int64

# %%
df['marital_status'] = df['marital_status'].replace({
    'married': 'Married',
    'never in union': 'Single',
    'divorced': 'Divorced',
    'no longer living together/separated': 'Separated',
    'widowed': 'Widowed',
    'living with partner': 'Living with partner'
})

print("Value counts for 'marital_status' after renaming:")
print(df['marital_status'].value_counts(dropna=False))
# Out:
# Value counts for 'marital_status' after renaming:
# marital_status
# Married                7358
# Single                 4628
# Divorced               1050
# Separated               453
# Widowed                 363
# Living with partner      99
# Name: count, dtype: int64
# /tmp/ipykernel_2464/4107072191.py:1: FutureWarning: The behavior of Series.replace (and DataFrame.replace) with CategoricalDtype is deprecated. In a future version, replace will only be used for cases that preserve the categories. To change the categories, use ser.cat.rename_categories instead.
#   df['marital_status'] = df['marital_status'].replace({

# %%
df.columns
# Out:
# Index(['v000', 'v001', 'v005', 'v007', 'respondent_age', 'residence_type',
#        'highest_edu_level', 'sex_of_household_head', 'age_of_household_head',
#        'freq_listen_radio', 'freq_watch_tv', 'owns_mobile_phone',
#        'wealth_index', 'current_contraceptive_method',
#        'visited_health_facility_12mo', 'smokes_cigarettes',
#        'permission_to_medical_Vist', 'money_needed_for_medical_vist',
#        'distance_to_health_facility', 'transport_for_medical_visit',
#        'waiting_time_concern_at_HF', 'covered_by_health_insurance',
#        'breast_exam_by_provider', 'cervical_cancer_tested', 'marital_status',
#        'age_at_first_sex', 'STI_last_12mo', 'genital_sore_last_12mo',
#        'genital_discharge_last_12mo', 'ever_tested_hiv',
#        'total_lifetime_sex_partners'],
#       dtype='object')

# %%
selected_columns = [
    'v005','respondent_age', 'residence_type',
     'highest_edu_level', 'sex_of_household_head', 'age_of_household_head',
       'freq_listen_radio', 'freq_watch_tv', 'owns_mobile_phone',
       'wealth_index', 'current_contraceptive_method',
       'visited_health_facility_12mo', 'smokes_cigarettes',
       'permission_to_medical_Vist', 'money_needed_for_medical_vist',
       'distance_to_health_facility', 'transport_for_medical_visit',
       'waiting_time_concern_at_HF', 'covered_by_health_insurance',
       'breast_exam_by_provider', 'cervical_cancer_tested', 'marital_status',
       'age_at_first_sex', 'STI_last_12mo', 'genital_sore_last_12mo',
       'genital_discharge_last_12mo', 'ever_tested_hiv',
       'total_lifetime_sex_partners'
]

df_selected = df[selected_columns]
display(df_selected.head())
# Out:
#      v005  respondent_age residence_type highest_edu_level  \
# 0  748300        0.794118          urban           primary
# 1  748300        0.794118          urban            higher
# 2  748300        0.264706          urban           primary
# 3  748300        0.205882          urban         secondary
# 4  748300        0.500000          urban           primary
#
#   sex_of_household_head  age_of_household_head freq_listen_radio  \
# 0                  male                 0.3625                No
# 1                female                 0.3250               Yes
# 2                female                 0.1125                No
# 3                  male                 0.1375                No
# 4                female                 0.2125                No
#
#   freq_watch_tv owns_mobile_phone wealth_index  ...  \
# 0            No               yes       richer  ...
# 1           Yes               yes      richest  ...
# 2            No               yes       richer  ...
# ...

# %%
df_selected.columns
# Out:
# Index(['v005', 'respondent_age', 'residence_type', 'highest_edu_level',
#        'sex_of_household_head', 'age_of_household_head', 'freq_listen_radio',
#        'freq_watch_tv', 'owns_mobile_phone', 'wealth_index',
#        'current_contraceptive_method', 'visited_health_facility_12mo',
#        'smokes_cigarettes', 'permission_to_medical_Vist',
#        'money_needed_for_medical_vist', 'distance_to_health_facility',
#        'transport_for_medical_visit', 'waiting_time_concern_at_HF',
#        'covered_by_health_insurance', 'breast_exam_by_provider',
#        'cervical_cancer_tested', 'marital_status', 'age_at_first_sex',
#        'STI_last_12mo', 'genital_sore_last_12mo',
#        'genital_discharge_last_12mo', 'ever_tested_hiv',
#        'total_lifetime_sex_partners'],
#       dtype='object')

# %%
df_selected.shape
# Out:
# (13951, 28)

# %%
df_selected = df_selected[df_selected['cervical_cancer_tested'] != 'don\'t know']
print("Rows with 'don't know' in 'cervical_cancer_tested' have been removed.")
print(f"New shape of DataFrame: {df_selected.shape}")
# Out:
# Rows with 'don't know' in 'cervical_cancer_tested' have been removed.
# New shape of DataFrame: (13909, 28)

# %%
df_selected.columns
# Out:
# Index(['v005', 'respondent_age', 'residence_type', 'highest_edu_level',
#        'sex_of_household_head', 'age_of_household_head', 'freq_listen_radio',
#        'freq_watch_tv', 'owns_mobile_phone', 'wealth_index',
#        'current_contraceptive_method', 'visited_health_facility_12mo',
#        'smokes_cigarettes', 'permission_to_medical_Vist',
#        'money_needed_for_medical_vist', 'distance_to_health_facility',
#        'transport_for_medical_visit', 'waiting_time_concern_at_HF',
#        'covered_by_health_insurance', 'breast_exam_by_provider',
#        'cervical_cancer_tested', 'marital_status', 'age_at_first_sex',
#        'STI_last_12mo', 'genital_sore_last_12mo',
#        'genital_discharge_last_12mo', 'ever_tested_hiv',
#        'total_lifetime_sex_partners'],
#       dtype='object')

# %%
df_selected = df_selected.drop(['genital_sore_last_12mo', 'genital_discharge_last_12mo', 'permission_to_medical_Vist', 'transport_for_medical_visit', 'money_needed_for_medical_vist'], axis=1)

# %%
df_selected.shape
# Out:
# (13909, 23)

# %%
df_selected.head()
# Out:
#      v005  respondent_age residence_type highest_edu_level  \
# 0  748300        0.794118          urban           primary
# 1  748300        0.794118          urban            higher
# 2  748300        0.264706          urban           primary
# 3  748300        0.205882          urban         secondary
# 4  748300        0.500000          urban           primary
#
#   sex_of_household_head  age_of_household_head freq_listen_radio  \
# 0                  male                 0.3625                No
# 1                female                 0.3250               Yes
# 2                female                 0.1125                No
# 3                  male                 0.1375                No
# 4                female                 0.2125                No
#
#   freq_watch_tv owns_mobile_phone wealth_index  ...  \
# 0            No               yes       richer  ...
# 1           Yes               yes      richest  ...
# 2            No               yes       richer  ...
# ...

# %%
df_selected.dtypes
# Out:
# v005                               int32
# respondent_age                   float64
# residence_type                  category
# highest_edu_level               category
# sex_of_household_head           category
# age_of_household_head            float64
# freq_listen_radio               category
# freq_watch_tv                   category
# owns_mobile_phone               category
# wealth_index                    category
# current_contraceptive_method    category
# visited_health_facility_12mo    category
# smokes_cigarettes               category
# distance_to_health_facility     category
# waiting_time_concern_at_HF      category
# covered_by_health_insurance     category
# breast_exam_by_provider         category
# cervical_cancer_tested          category
# marital_status                  category
# age_at_first_sex                  object
# STI_last_12mo                   category
# ever_tested_hiv                 category
# total_lifetime_sex_partners      float64
# ...

# %%
df_selected.columns
# Out:
# Index(['v005', 'respondent_age', 'residence_type', 'highest_edu_level',
#        'sex_of_household_head', 'age_of_household_head', 'freq_listen_radio',
#        'freq_watch_tv', 'owns_mobile_phone', 'wealth_index',
#        'current_contraceptive_method', 'visited_health_facility_12mo',
#        'smokes_cigarettes', 'distance_to_health_facility',
#        'waiting_time_concern_at_HF', 'covered_by_health_insurance',
#        'breast_exam_by_provider', 'cervical_cancer_tested', 'marital_status',
#        'age_at_first_sex', 'STI_last_12mo', 'ever_tested_hiv',
#        'total_lifetime_sex_partners'],
#       dtype='object')

# %%
for column in df_selected.columns:
    print(f"\nCategories in '{column}':")
    print(df_selected[column].unique())
# Out:
# Categories in 'v005':
# [ 748300  648166  602223  954721 1428342  947616  812401  844346  728506
#  1657092  962106  884874  684300  783721 1178616  743363  711502 1116593
#   796290 1039854 1019175 1331064  776798  887333 1012676  987834  869127
#  1089577  891862 1007098  787368 1441977 1666388  686053  952222  989920
#   473589  805665  782147  633310 1909571  907357  560093  545608  698956
#  1259600  920350 1302404  921747  641374  703860  806789  787548  573775
#   842173  644922  767581 1789394 1651732 1456848  701612  782641 2359221
#   840379 3347311 1044939 1266733  645238  792882 1001155  755396 1083617
#   740938  512185 1081667  875845 1133188  752568  575223  636467  724729
#   696351  765216 1719542  640538  591866  830359  681279  836944 1025900
#  1458801  909260  774929 1493623 1109325  857820  891957  947619  705429
#   969126  987385 1990447 1910321 1013127  719723  281023  673027 1117664
#   774934  802149  730336 1322633 1089479  705714  886791  990733  781598
# ...

# %%
import pandas as pd
import numpy as np

# Replace "don't know" with NaN
df_selected = df_selected.replace("don't know", np.nan)

# Mode imputation for each column
for column in df_selected.columns:
    if df_selected[column].isnull().any():
        mode_value = df_selected[column].mode(dropna=True)[0]  # Get the most frequent value
        # Fix: Avoid inplace=True on a potentially read-only view by reassigning
        df_selected[column] = df_selected[column].fillna(mode_value)

# Optional: check the updated dataframe
print(df_selected.head())
# Out:
#      v005  respondent_age residence_type highest_edu_level  \
# 0  748300        0.794118          urban           primary
# 1  748300        0.794118          urban            higher
# 2  748300        0.264706          urban           primary
# 3  748300        0.205882          urban         secondary
# 4  748300        0.500000          urban           primary
#
#   sex_of_household_head  age_of_household_head freq_listen_radio  \
# 0                  male                 0.3625                No
# 1                female                 0.3250               Yes
# 2                female                 0.1125                No
# 3                  male                 0.1375                No
# 4                female                 0.2125                No
#
#   freq_watch_tv owns_mobile_phone wealth_index  ...  \
# 0            No               yes       richer  ...
# 1           Yes               yes      richest  ...
# 2            No               yes       richer  ...
# ...

# %%
for column in df_selected.columns:
    print(f"\nCategories in '{column}':")
    print(df_selected[column].unique())
# Out:
# Categories in 'v005':
# [ 748300  648166  602223  954721 1428342  947616  812401  844346  728506
#  1657092  962106  884874  684300  783721 1178616  743363  711502 1116593
#   796290 1039854 1019175 1331064  776798  887333 1012676  987834  869127
#  1089577  891862 1007098  787368 1441977 1666388  686053  952222  989920
#   473589  805665  782147  633310 1909571  907357  560093  545608  698956
#  1259600  920350 1302404  921747  641374  703860  806789  787548  573775
#   842173  644922  767581 1789394 1651732 1456848  701612  782641 2359221
#   840379 3347311 1044939 1266733  645238  792882 1001155  755396 1083617
#   740938  512185 1081667  875845 1133188  752568  575223  636467  724729
#   696351  765216 1719542  640538  591866  830359  681279  836944 1025900
#  1458801  909260  774929 1493623 1109325  857820  891957  947619  705429
#   969126  987385 1990447 1910321 1013127  719723  281023  673027 1117664
#   774934  802149  730336 1322633 1089479  705714  886791  990733  781598
# ...

# %%
df_selected.shape
# Out:
# (13909, 23)

# %%
df_selected.dtypes
# Out:
# v005                               int32
# respondent_age                   float64
# residence_type                  category
# highest_edu_level               category
# sex_of_household_head           category
# age_of_household_head            float64
# freq_listen_radio               category
# freq_watch_tv                   category
# owns_mobile_phone               category
# wealth_index                    category
# current_contraceptive_method    category
# visited_health_facility_12mo    category
# smokes_cigarettes               category
# distance_to_health_facility     category
# waiting_time_concern_at_HF      category
# covered_by_health_insurance     category
# breast_exam_by_provider         category
# cervical_cancer_tested          category
# marital_status                  category
# age_at_first_sex                  object
# STI_last_12mo                   category
# ever_tested_hiv                 category
# total_lifetime_sex_partners      float64
# ...

# %%
df_selected.columns
# Out:
# Index(['v005', 'respondent_age', 'residence_type', 'highest_edu_level',
#        'sex_of_household_head', 'age_of_household_head', 'freq_listen_radio',
#        'freq_watch_tv', 'owns_mobile_phone', 'wealth_index',
#        'current_contraceptive_method', 'visited_health_facility_12mo',
#        'smokes_cigarettes', 'distance_to_health_facility',
#        'waiting_time_concern_at_HF', 'covered_by_health_insurance',
#        'breast_exam_by_provider', 'cervical_cancer_tested', 'marital_status',
#        'age_at_first_sex', 'STI_last_12mo', 'ever_tested_hiv',
#        'total_lifetime_sex_partners'],
#       dtype='object')

# %%
for column in df_selected.columns:
    if column == 'v005' or column == 'weight':
        continue
    print(f"\nCategories in '{column}':")
    print(df_selected[column].unique())
# Out:
# Categories in 'respondent_age':
# [0.79411765 0.26470588 0.20588235 0.5        0.61764706 0.32352941
#  0.23529412 0.41176471 1.         0.11764706 0.05882353 0.97058824
#  0.85294118 0.14705882 0.88235294 0.52941176 0.67647059 0.91176471
#  0.02941176 0.08823529 0.55882353 0.82352941 0.17647059 0.76470588
#  0.64705882 0.29411765 0.44117647 0.73529412 0.94117647 0.38235294
#  0.35294118 0.47058824 0.         0.70588235 0.58823529]
#
# Categories in 'residence_type':
# ['urban', 'rural']
# Categories (2, object): ['urban' < 'rural']
#
# Categories in 'highest_edu_level':
# ['primary', 'higher', 'secondary', 'no education']
# Categories (4, object): ['no education' < 'primary' < 'secondary' < 'higher']
#
# Categories in 'sex_of_household_head':
# ['male', 'female']
# Categories (2, object): ['male' < 'female']
#
# Categories in 'age_of_household_head':
# [0.3625 0.325  0.1125 0.1375 0.2125 0.2625 0.1    0.1875 0.55   0.3125
# ...

# %%
import pandas as pd

# Target columns for the descriptive table
descriptive_columns = [
    'residence_type', 'highest_edu_level', 'sex_of_household_head',
    'freq_listen_radio', 'freq_watch_tv', 'owns_mobile_phone', 'wealth_index',
    'current_contraceptive_method', 'visited_health_facility_12mo', 'smokes_cigarettes',
    'distance_to_health_facility', 'waiting_time_concern_at_HF',
    'covered_by_health_insurance', 'breast_exam_by_provider', 'cervical_cancer_tested',
    'marital_status', 'age_at_first_sex', 'STI_last_12mo', 'ever_tested_hiv'
]

# Ensure weight column exists if not already present
if 'weight' not in df_selected.columns:
    df_selected['weight'] = df_selected['v005'] / 1_000_000

descriptive_table_data = []

for col in descriptive_columns:
    # Ensure column exists in dataframe to avoid KeyErrors
    if col not in df_selected.columns:
        print(f"Warning: '{col}' not found in df_selected. Skipping.")
        continue

    # Cast to object/string first to avoid Categorical setitem restrictions,
    # then handle null values safely
    temp_series = df_selected[col].astype(object).fillna("Missing").astype(str)

    # Group by categories and compute weighted sums
    weighted_counts = df_selected.groupby(temp_series)['weight'].sum()
    total_weighted_sum = weighted_counts.sum()

    # Calculate weighted percentages
    weighted_percentages = (weighted_counts / total_weighted_sum) * 100

    for category, count in weighted_counts.items():
        percent = weighted_percentages.get(category, 0)
        descriptive_table_data.append({
            'Variables': col,
            'Category': str(category),
            'Weighted_Count': int(round(count)),
            'Weighted_Percent': round(percent, 1)
        })

# Create final descriptive DataFrame
descriptive_table = pd.DataFrame(descriptive_table_data)

# Save to CSV
csv_filename = "descriptive_table_weighted.csv"
descriptive_table.to_csv(csv_filename, index=False)
print(f"Table successfully exported to '{csv_filename}'\n")

# Display in notebook environment
print("Descriptive Table with Weighted Counts and Percentages:")
display(descriptive_table)
# Out:
# Table successfully exported to 'descriptive_table_weighted.csv'
#
# Descriptive Table with Weighted Counts and Percentages:
#                        Variables             Category  Weighted_Count  \
# 0                 residence_type                rural            6831
# 1                 residence_type                urban            7081
# 2              highest_edu_level               higher            1079
# 3              highest_edu_level         no education             898
# 4              highest_edu_level              primary            5459
# 5              highest_edu_level            secondary            6476
# 6          sex_of_household_head               female            4593
# 7          sex_of_household_head                 male            9319
# 8              freq_listen_radio                   No            9255
# 9              freq_listen_radio                  Yes            4658
# 10                 freq_watch_tv                   No            8731
# ...

# %%
df_selected.head()
# Out:
#      v005  respondent_age residence_type highest_edu_level  \
# 0  748300        0.794118          urban           primary
# 1  748300        0.794118          urban            higher
# 2  748300        0.264706          urban           primary
# 3  748300        0.205882          urban         secondary
# 4  748300        0.500000          urban           primary
#
#   sex_of_household_head  age_of_household_head freq_listen_radio  \
# 0                  male                 0.3625                No
# 1                female                 0.3250               Yes
# 2                female                 0.1125                No
# 3                  male                 0.1375                No
# 4                female                 0.2125                No
#
#   freq_watch_tv owns_mobile_phone wealth_index  ...  \
# 0            No               yes       richer  ...
# 1           Yes               yes      richest  ...
# 2            No               yes       richer  ...
# ...

# %%
encoding_maps = {
    'residence_type': {
        'urban': 0,
        'rural': 1
    },

    'highest_edu_level': {
        'no education': 0,
        'primary': 1,
        'secondary': 2,
        'higher': 3
    },

    'sex_of_household_head': {
        'male': 1,
        'female': 0
    },

    'freq_listen_radio': {
        'No': 0,
        'Yes': 1
    },

    'freq_watch_tv': {
        'No': 0,
        'Yes': 1
    },

    'owns_mobile_phone': {
        'no': 0,
        'yes': 1
    },

    'wealth_index': {
        'poorest': 1,
        'poorer': 2,
        'middle': 3,
        'richer': 4,
        'richest': 5
    },

    'current_contraceptive_method': {
        'Non-Hormonal': 0,
        'Hormonal': 1
    },

    'visited_health_facility_12mo': {
        'yes': 1,
        'no': 0
    },

    'smokes_cigarettes': {
        'no': 0,
        'yes': 1
    },

    'distance_to_health_facility': {
        'not a big problem': 0,
        'big problem': 1
    },

    'waiting_time_concern_at_HF': {
        'not a big problem': 0,
        'big problem': 1
    },

    'covered_by_health_insurance': {
        'no': 0,
        'yes': 1
    },

    'breast_exam_by_provider': {
        'no': 0,
        'yes': 1
    },

    'cervical_cancer_tested': {
        'no': 0,
        'yes': 1
    },

    'marital_status': {
        'Single': 1,
        'Married': 3,
        'Living with partner': 2,
        'Widowed': 6,
        'Divorced': 5,
        'Separated': 4
    },

    'age_at_first_sex': {
        'not had sex': 1,
        '<15': 2,
        '15-17': 3,
        '18-19': 4,
        '>20': 5
    },

    'STI_last_12mo': {
        'no': 0,
        'yes': 1
    },

    'ever_tested_hiv': {
        'yes': 1,
        'no': 0
    }
}

# %%
for col, mapping in encoding_maps.items():
    if col in df_selected.columns:
        df_selected[col] = df_selected[col].map(mapping)

        # Check unmapped values
        unmatched = set(df_selected[col].isna().index)

# %%
df_selected = df_selected.drop(columns=['v005', 'weight'])

# %%
df_selected.head()
# Out:
#    respondent_age residence_type highest_edu_level sex_of_household_head  \
# 0        0.794118              0                 1                     1
# 1        0.794118              0                 3                     0
# 2        0.264706              0                 1                     0
# 3        0.205882              0                 2                     1
# 4        0.500000              0                 1                     0
#
#    age_of_household_head freq_listen_radio freq_watch_tv owns_mobile_phone  \
# 0                 0.3625                 0             0                 1
# 1                 0.3250                 1             1                 1
# 2                 0.1125                 0             0                 1
# 3                 0.1375                 0             0                 1
# 4                 0.2125                 0             0                 1
#
# ...

# %%
df_selected.columns
# Out:
# Index(['respondent_age', 'residence_type', 'highest_edu_level',
#        'sex_of_household_head', 'age_of_household_head', 'freq_listen_radio',
#        'freq_watch_tv', 'owns_mobile_phone', 'wealth_index',
#        'current_contraceptive_method', 'visited_health_facility_12mo',
#        'smokes_cigarettes', 'distance_to_health_facility',
#        'waiting_time_concern_at_HF', 'covered_by_health_insurance',
#        'breast_exam_by_provider', 'cervical_cancer_tested', 'marital_status',
#        'age_at_first_sex', 'STI_last_12mo', 'ever_tested_hiv',
#        'total_lifetime_sex_partners'],
#       dtype='object')

# %%
rename_map = {
    'respondent_age': 'age',
    'residence_type': 'residence',
    'highest_edu_level': 'education_level',
    'sex_of_household_head': 'household_head_sex',
    'age_of_household_head': 'household_head_age',
    'freq_listen_radio': 'listen_radio',
    'freq_watch_tv': 'watch_tv',
    'owns_mobile_phone': 'mobile_phone',
    'wealth_index': 'wealth_index',
    'current_contraceptive_method': 'contraceptive_method',
    'visited_health_facility_12mo': 'visited_health_facility_12mo',
    'smokes_cigarettes': 'smokes_cigarettes',
    'distance_to_health_facility': 'distance_to_Helth_facility',
    'waiting_time_concern_at_HF': 'facility_waiting_time',
    'covered_by_health_insurance': 'health_insurance',
    'breast_exam_by_provider': 'breast_exam',
    'cervical_cancer_tested': 'cervical_cancer_screened',
    'marital_status': 'marital_status',
    'age_at_first_sex': 'age_first_sex',
    'STI_last_12mo': 'STI_last12mo',
    'ever_tested_hiv': 'ever_tested_hiv',
    'total_lifetime_sex_partners': 'lifetime_sex_partners'
}

df_selected = df_selected.rename(columns=rename_map)

# %%
df_selected.head()
# Out:
#         age residence education_level household_head_sex  household_head_age  \
# 0  0.794118         0               1                  1              0.3625
# 1  0.794118         0               3                  0              0.3250
# 2  0.264706         0               1                  0              0.1125
# 3  0.205882         0               2                  1              0.1375
# 4  0.500000         0               1                  0              0.2125
#
#   listen_radio watch_tv mobile_phone wealth_index contraceptive_method  ...  \
# 0            0        0            1            4                    0  ...
# 1            1        1            1            5                    0  ...
# 2            0        0            1            4                    1  ...
# 3            0        0            1            3                    1  ...
# 4            0        0            1            2                    1  ...
#
# ...

# %%
df_selected.isna().sum()
# Out:
# age                             0
# residence                       0
# education_level                 0
# household_head_sex              0
# household_head_age              0
# listen_radio                    0
# watch_tv                        0
# mobile_phone                    0
# wealth_index                    0
# contraceptive_method            0
# visited_health_facility_12mo    0
# smokes_cigarettes               0
# distance_to_Helth_facility      0
# facility_waiting_time           0
# health_insurance                0
# breast_exam                     0
# cervical_cancer_screened        0
# marital_status                  0
# age_first_sex                   0
# STI_last12mo                    0
# ever_tested_hiv                 0
# lifetime_sex_partners           0
# dtype: int64

# %%
df_selected.dtypes
# Out:
# age                              float64
# residence                       category
# education_level                 category
# household_head_sex              category
# household_head_age               float64
# listen_radio                    category
# watch_tv                        category
# mobile_phone                    category
# wealth_index                    category
# contraceptive_method            category
# visited_health_facility_12mo    category
# smokes_cigarettes               category
# distance_to_Helth_facility      category
# facility_waiting_time           category
# health_insurance                category
# breast_exam                     category
# cervical_cancer_screened        category
# marital_status                  category
# age_first_sex                      int64
# STI_last12mo                    category
# ever_tested_hiv                 category
# lifetime_sex_partners            float64
# dtype: object

# %%
import pandas as pd

# Convert all columns to numeric, invalid parsing will be set as NaN
df_selected = df_selected.apply(pd.to_numeric, errors='coerce')

# Check the result
print(df_selected.dtypes)
# Out:
# age                             float64
# residence                         int64
# education_level                   int64
# household_head_sex                int64
# household_head_age              float64
# listen_radio                      int64
# watch_tv                          int64
# mobile_phone                      int64
# wealth_index                      int64
# contraceptive_method              int64
# visited_health_facility_12mo      int64
# smokes_cigarettes                 int64
# distance_to_Helth_facility        int64
# facility_waiting_time             int64
# health_insurance                  int64
# breast_exam                       int64
# cervical_cancer_screened          int64
# marital_status                    int64
# age_first_sex                     int64
# STI_last12mo                      int64
# ever_tested_hiv                   int64
# lifetime_sex_partners           float64
# dtype: object

# %%
df_selected.columns
# Out:
# Index(['age', 'residence', 'education_level', 'household_head_sex',
#        'household_head_age', 'listen_radio', 'watch_tv', 'mobile_phone',
#        'wealth_index', 'contraceptive_method', 'visited_health_facility_12mo',
#        'smokes_cigarettes', 'distance_to_Helth_facility',
#        'facility_waiting_time', 'health_insurance', 'breast_exam',
#        'cervical_cancer_screened', 'marital_status', 'age_first_sex',
#        'STI_last12mo', 'ever_tested_hiv', 'lifetime_sex_partners'],
#       dtype='object')

# %%
# --- Define target and features ---
y = df_selected["cervical_cancer_screened"]
X = df_selected.drop(columns=["cervical_cancer_screened"])

# %%
import matplotlib.pyplot as plt

# Map 0/1 to No/Yes
y_mapped = df_selected["cervical_cancer_screened"].map({0: "No", 1: "Yes"})

# Calculate counts
counts = y_mapped.value_counts()
labels = counts.index
sizes = counts.values
colors = ['#ff9999','#66b3ff']  # Nice color palette

# Plot pie chart
plt.figure(figsize=(7,7))
plt.pie(
    sizes,
    labels=labels,
    autopct='%1.1f%%',  # Show percentage
    startangle=140,     # Rotation
    colors=colors,
    wedgeprops={'edgecolor': 'black', 'linewidth': 1.2},  # Black border for wedges
    textprops={'fontsize': 12}
)
plt.title("Prportion of Cervical Cancer Screening", fontsize=16)
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
from math import sqrt

# Map 0/1 to No/Yes
y_mapped = df_selected["cervical_cancer_screened"].map({0: "No", 1: "Yes"})

# Counts
counts = y_mapped.value_counts()
n = counts.sum()

# Proportions
proportions = counts / n

# 95% CI (Normal approximation)
z = 1.96
ci_lower = proportions - z * np.sqrt((proportions * (1 - proportions)) / n)
ci_upper = proportions + z * np.sqrt((proportions * (1 - proportions)) / n)

# Create labels with CI
labels = [
    f"{label}\n{prop*100:.1f}% (95% CI: {low*100:.1f}–{up*100:.1f})"
    for label, prop, low, up in zip(
        proportions.index, proportions.values, ci_lower.values, ci_upper.values
    )
]

sizes = proportions.values
colors = ['#ff9999', '#66b3ff']
plt.figure(figsize=(7, 7))
plt.pie(
    sizes,
    labels=labels,
    startangle=140,
    colors=colors,
    wedgeprops={'edgecolor': 'black', 'linewidth': 1.2},
    textprops={'fontsize': 12}
)

plt.title("Proportion of Cervical Cancer Screening (95% CI)", fontsize=16)
plt.show()

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# Select only numeric features
numeric_features = df_selected.select_dtypes(include=['int64', 'float64'])

# Compute correlation matrix
corr_matrix = numeric_features.corr()

# Display correlation matrix as a heatmap
plt.figure(figsize=(16, 14))  # Increased figure size
sns.set(font_scale=1)       # Increase font scale for better readability
sns.heatmap(
    corr_matrix,
    annot=True,                # Show correlation values
    fmt=".2f",                 # Format
    cmap="coolwarm",           # Color map
    linewidths=1,              # Line width between cells
    cbar_kws={'shrink': 0.8}, # Colorbar size
    square=True
)
plt.xticks(rotation=45, ha='right', fontsize=12)
plt.yticks(rotation=0, fontsize=12)
plt.title("Correlation Matrix", fontsize=16)
plt.tight_layout()
plt.show()

# %%
#df_selected=df_selected.drop(['residence'],axis=1) # have higher correlation with wealth index

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# Select only numeric features
numeric_features = df_selected.select_dtypes(include=['int64', 'float64'])

# Compute correlation matrix
corr_matrix = numeric_features.corr()

# Display correlation matrix as a heatmap
plt.figure(figsize=(16, 14))  # Increased figure size
sns.set(font_scale=1)       # Increase font scale for better readability
sns.heatmap(
    corr_matrix,
    annot=True,                # Show correlation values
    fmt=".2f",                 # Format
    cmap="coolwarm",           # Color map
    linewidths=1,              # Line width between cells
    cbar_kws={'shrink': 0.8}, # Colorbar size
    square=True
)
plt.xticks(rotation=45, ha='right', fontsize=12)
plt.yticks(rotation=0, fontsize=12)
plt.title("Correlation Matrix", fontsize=16)
plt.tight_layout()
plt.show()

# %%
from sklearn.model_selection import train_test_split

# Assuming X contains features and y contains the target
# Split data: 80% train, 20% test
X_train, X_test, y_train, y_test = train_test_split(
    X, y,
    test_size=0.2,       # 20% for testing
    random_state=42,     # for reproducibility
    stratify=y           # keeps class distribution same in train and test
)

# Check the shape
print("X_train:", X_train.shape)
print("X_test:", X_test.shape)
print("y_train distribution:\n", y_train.value_counts())
print("y_test distribution:\n", y_test.value_counts())
# Out:
# X_train: (11127, 21)
# X_test: (2782, 21)
# y_train distribution:
#  cervical_cancer_screened
# 0    8183
# 1    2944
# Name: count, dtype: int64
# y_test distribution:
#  cervical_cancer_screened
# 0    2046
# 1     736
# Name: count, dtype: int64

# %%
import matplotlib.pyplot as plt
import seaborn as sns
from imblearn.over_sampling import SMOTENC # Changed from SMOTE
import pandas as pd

# ensure using training set only
y_train_mapped = y_train.map({0: "No", 1: "Yes"})

# Identify categorical features for SMOTENC
categorical_features_indices = [X_train.columns.get_loc(col) for col in X_train.select_dtypes(include=['int64']).columns if col != 'age_first_sex']

# Apply SMOTENC on training data only
smote_nc = SMOTENC(categorical_features=categorical_features_indices, random_state=42)
X_train_res, y_train_res = smote_nc.fit_resample(X_train, y_train)

y_train_res_mapped = pd.Series(y_train_res).map({0: "No", 1: "Yes"})

fig, axes = plt.subplots(1, 2, figsize=(12, 5))
order = ["No", "Yes"]  # explicit category order used for both plots

# Before SMOTE
sns.countplot(x=y_train_mapped, order=order, palette="Set2", ax=axes[0])
axes[0].set_title("Before SMOTENC", fontsize=14)
axes[0].set_xlabel("Cervical Cancer Screened", fontsize=12)
axes[0].set_ylabel("Count", fontsize=12)

# Annotate counts by reading bar heights (robust)
for p in axes[0].patches:
    height = int(p.get_height())
    axes[0].text(p.get_x() + p.get_width() / 2., height + 5, str(height),
                 ha="center", fontsize=12)

# After SMOTE
sns.countplot(x=y_train_res_mapped, order=order, palette="Set2", ax=axes[1])
axes[1].set_title("After SMOTENC", fontsize=14)
axes[1].set_xlabel("Cervical Cancer Screened", fontsize=12)
axes[1].set_ylabel("Count", fontsize=12)

for p in axes[1].patches:
    height = int(p.get_height())
    axes[1].text(p.get_x() + p.get_width() / 2., height + 5, str(height),
                 ha="center", fontsize=12)

plt.tight_layout()
plt.show()
# Out:
# /tmp/ipykernel_2464/2489723028.py:22: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(x=y_train_mapped, order=order, palette="Set2", ax=axes[0])
# /tmp/ipykernel_2464/2489723028.py:34: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(x=y_train_res_mapped, order=order, palette="Set2", ax=axes[1])

# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
from sklearn.ensemble import RandomForestClassifier
from sklearn.feature_selection import RFE

# -------------------------------------------------------
# 1. Random Forest Classifier
# -------------------------------------------------------
rf = RandomForestClassifier(
    n_estimators=300,
    random_state=42,
    class_weight=None,
    n_jobs=-1  # Parallelize tree building across all cores
)

# -------------------------------------------------------
# 2. Apply RFE to select the top 10 features
# -------------------------------------------------------
TARGET_FEATURES = 10

rfe = RFE(
    estimator=rf,
    n_features_to_select=TARGET_FEATURES,
    step=1
)

rfe.fit(X_train_res, y_train_res)

# -------------------------------------------------------
# 3. Build Ranking & Importance Table
# -------------------------------------------------------
# Fit a standalone estimator on all features to obtain overall Gini importance values
rf.fit(X_train_res, y_train_res)
feature_importances = rf.feature_importances_

ranking_df = pd.DataFrame({
    "Feature": X_train_res.columns,
    "Rank": rfe.ranking_,
    "Selected": rfe.support_,
    "Importance": feature_importances
}).sort_values(by=["Rank", "Importance"], ascending=[True, False]).reset_index(drop=True)

print("\nFeature Ranking (1 = Selected in Top 10):")
print(ranking_df)

# -------------------------------------------------------
# 4. Show only the top 10 selected features
# -------------------------------------------------------
top_10_df = ranking_df[ranking_df["Selected"]].copy().reset_index(drop=True)
print(f"\nTop {TARGET_FEATURES} Selected Features:")
print(top_10_df[["Feature", "Importance", "Rank"]])

# -------------------------------------------------------
# 5. High-Quality Publication Plot
# -------------------------------------------------------
# Set publication visual parameters
plt.rcParams.update({
    "font.family": "sans-serif",
    "font.sans-serif": ["DejaVu Sans", "Arial", "Helvetica"],
    "axes.edgecolor": "#333333",
    "axes.linewidth": 0.8,
    "xtick.color": "#333333",
    "ytick.color": "#333333"
})

# Sort for plotting: rank 1 at top, lower importance below
plot_df = ranking_df.sort_values(by=["Rank", "Importance"], ascending=[False, True]).reset_index(drop=True)

fig, ax = plt.subplots(figsize=(9, max(6, len(plot_df) * 0.38)), dpi=300)

# Colors: Deep navy for selected top 10, clean slate grey for unselected
palette = ["#1A5276" if sel else "#BDC3C7" for sel in plot_df["Selected"]]

bars = ax.barh(
    y=plot_df["Feature"],
    width=plot_df["Importance"],
    color=palette,
    edgecolor="none",
    height=0.68
)

# Annotate bars with percentage contribution
max_val = plot_df["Importance"].max()
for bar, sel in zip(bars, plot_df["Selected"]):
    val = bar.get_width()
    text_color = "#1A5276" if sel else "#7F8C8D"
    fontweight = "bold" if sel else "normal"
    ax.text(
        val + (max_val * 0.012),
        bar.get_y() + bar.get_height() / 2,
        f"{val * 100:.1f}%",
        va="center",
        ha="left",
        fontsize=9,
        color=text_color,
        fontweight=fontweight
    )

# Formatting axes and spines
ax.set_title(
    f"Recursive Feature Elimination (RFE) — Top {TARGET_FEATURES} Predictors",
    fontsize=13,
    fontweight="bold",
    pad=14,
    loc="left",
    color="#111111"
)
ax.set_xlabel("Random Forest Mean Gini Importance", fontsize=11, labelpad=8, color="#222222")
ax.set_ylabel("Features", fontsize=11, labelpad=8, color="#222222")

# Clean axis borders
ax.spines["top"].set_visible(False)
ax.spines["right"].set_visible(False)
ax.spines["left"].set_color("#cccccc")
ax.spines["bottom"].set_color("#cccccc")

# Subtle horizontal grid for row scanning
ax.grid(axis="x", linestyle="--", alpha=0.4, color="#888888")
ax.set_axisbelow(True)

# Extend x-axis slightly to accommodate percentage labels
ax.set_xlim(0, max_val * 1.15)
ax.tick_params(axis="both", which="major", labelsize=9.5)

plt.tight_layout()

# Save in high-res raster (600 DPI) and vector formats
plt.savefig("RFE_top10_feature_ranking.png", dpi=600, bbox_inches="tight")
plt.savefig("RFE_top10_feature_ranking.pdf", bbox_inches="tight")
plt.show()

# -------------------------------------------------------
# 6. Extract Transformed Datasets (Top 10 Features)
# -------------------------------------------------------
X_train_selected = rfe.transform(X_train_res)
# X_test_selected  = rfe.transform(X_test)
# Out:
# Feature Ranking (1 = Selected in Top 10):
#                          Feature  Rank  Selected  Importance
# 0                            age     1      True    0.233729
# 1             household_head_age     1      True    0.153881
# 2          lifetime_sex_partners     1      True    0.093524
# 3                  age_first_sex     1      True    0.062246
# 4                    breast_exam     1      True    0.059602
# 5                   wealth_index     1      True    0.052866
# 6                 marital_status     1      True    0.048529
# 7                education_level     1      True    0.039045
# 8                ever_tested_hiv     1      True    0.034363
# 9                   mobile_phone     1      True    0.028215
# 10                  listen_radio     2     False    0.024614
# 11          contraceptive_method     3     False    0.025314
# 12         facility_waiting_time     4     False    0.023367
# 13    distance_to_Helth_facility     5     False    0.021271
# ...

# %%
# !pip -q install optuna
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 442.4/442.4 kB 18.0 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 268.7/268.7 kB 13.5 MB/s eta 0:00:00

# %%
# !pip -q install catboost
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 97.1/97.1 MB 8.8 MB/s eta 0:00:00

# %%
# ======================================================
# Full pipeline: Optuna + Final Models + Evaluation + ROC
# Revised with specified model list (LR, DT, RF, ET, XGBoost, CatBoost)
# ======================================================

import warnings
warnings.filterwarnings("ignore")

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# ML libraries
import optuna
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import StandardScaler
from sklearn.utils import resample

# Models
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import (
    RandomForestClassifier, ExtraTreesClassifier
)
from sklearn.linear_model import LogisticRegression

from xgboost import XGBClassifier
from catboost import CatBoostClassifier

# Metrics (added classification_report)
from sklearn.metrics import (
    roc_auc_score, average_precision_score,
    accuracy_score, precision_score, recall_score,
    f1_score, roc_curve, confusion_matrix,
    classification_report
)


# ======================================================
# 0. RFE-selected features
# ======================================================
selected_features = ranking_df[ranking_df["Selected"] == True]["Feature"].tolist()
print("Selected features (RFE):", selected_features)

X_train_sel = X_train_res[selected_features].copy()
X_test_sel  = X_test[selected_features].copy()

assert X_train_sel.shape[1] == len(selected_features)


# ======================================================
# Evaluation function
# ======================================================
def evaluate_model(name, model, X_test, y_test):
    try:
        probs = model.predict_proba(X_test)[:, 1]
    except Exception:
        try:
            scores = model.decision_function(X_test)
            probs = (scores - scores.min()) / (scores.max() - scores.min())
        except Exception:
            probs = model.predict(X_test)

    preds = (probs >= 0.5).astype(int)

    cm = confusion_matrix(y_test, preds)
    tn, fp, fn, tp = cm.ravel()

    specificity = tn / (tn + fp) if (tn + fp) > 0 else 0

    return {
        "model": name,
        "roc_auc": roc_auc_score(y_test, probs),
        "pr_auc": average_precision_score(y_test, probs),
        "accuracy": accuracy_score(y_test, preds),
        "precision": precision_score(y_test, preds, zero_division=0),
        "recall": recall_score(y_test, preds, zero_division=0),
        "f1": f1_score(y_test, preds, zero_division=0),
        "specificity": specificity,
        "confusion_matrix": cm,
        "probs": probs
    }

# Helper function to calculate bootstrap confidence intervals
def bootstrap_metric_ci(y_true, y_pred_proba, metric_name, n_bootstraps=500, alpha=0.05):
    """
    Calculates bootstrap confidence interval for a given metric.
    y_pred_proba should be probabilities for the positive class.
    metric_name: string identifier for the metric (e.g., "roc_auc", "accuracy")
    """
    n_samples = len(y_true)
    bootstrapped_scores = []

    # Convert y_true to numpy array for consistent indexing if it's a pandas Series
    y_true_np = y_true.to_numpy() if isinstance(y_true, pd.Series) else y_true

    # Convert y_pred_proba to numpy array if it's not already
    y_pred_proba_np = y_pred_proba.to_numpy() if isinstance(y_pred_proba, pd.Series) else y_pred_proba

    for _ in range(n_bootstraps):
        indices = resample(np.arange(n_samples), random_state=np.random.randint(0, 100000))
        y_true_bootstrap = y_true_np[indices]
        y_pred_proba_bootstrap = y_pred_proba_np[indices]

        # Ensure y_pred (0 or 1) for metrics that need it
        y_pred_bootstrap = (y_pred_proba_bootstrap >= 0.5).astype(int)

        score = None
        try:
            if metric_name == "roc_auc":
                # Check for single class in bootstrap sample which breaks AUC
                if len(np.unique(y_true_bootstrap)) < 2:
                    continue
                score = roc_auc_score(y_true_bootstrap, y_pred_proba_bootstrap)
            elif metric_name == "pr_auc":
                # Check for single class in bootstrap sample which breaks PR-AUC
                if len(np.unique(y_true_bootstrap)) < 2:
                    continue
                score = average_precision_score(y_true_bootstrap, y_pred_proba_bootstrap)
            elif metric_name == "accuracy":
                score = accuracy_score(y_true_bootstrap, y_pred_bootstrap)
            elif metric_name == "precision":
                score = precision_score(y_true_bootstrap, y_pred_bootstrap, zero_division=0)
            elif metric_name == "recall":
                score = recall_score(y_true_bootstrap, y_pred_bootstrap, zero_division=0)
            elif metric_name == "f1":
                score = f1_score(y_true_bootstrap, y_pred_bootstrap, zero_division=0)
            elif metric_name == "specificity":
                cm = confusion_matrix(y_true_bootstrap, y_pred_bootstrap)
                tn, fp, fn, tp = cm.ravel()
                score = tn / (tn + fp) if (tn + fp) > 0 else 0

            if score is not None:
                bootstrapped_scores.append(score)
        except Exception:
            # Silently skip errors during bootstrap
            pass

    bootstrapped_scores = np.array(bootstrapped_scores)

    # Filter out NaNs or infinities if any occurred
    bootstrapped_scores = bootstrapped_scores[np.isfinite(bootstrapped_scores)]

    if len(bootstrapped_scores) < (n_bootstraps * 0.9):  # If too many failed, return NaN
        return (np.nan, np.nan)

    # Calculate percentile-based CI
    lower = np.percentile(bootstrapped_scores, (alpha / 2) * 100)
    upper = np.percentile(bootstrapped_scores, (1 - alpha / 2) * 100)
    return (lower, upper)


# ======================================================
# 1. Optuna Objective Functions
# ======================================================

def optimize_decisiontree(trial):
    params = {
        "max_depth": trial.suggest_int("max_depth", 2, 30),
        "min_samples_split": trial.suggest_int("min_samples_split", 2, 10),
        "random_state": 42
    }
    model = DecisionTreeClassifier(**params)
    model.fit(X_train_sel, y_train_res)
    preds = model.predict_proba(X_test_sel)[:, 1]
    return roc_auc_score(y_test, preds)


def optimize_rf(trial):
    params = {
        "n_estimators": trial.suggest_int("n_estimators", 100, 600),
        "max_depth": trial.suggest_int("max_depth", 3, 30),
        "min_samples_split": trial.suggest_int("min_samples_split", 2, 10),
        "random_state": 42
    }
    model = RandomForestClassifier(**params, n_jobs=-1)
    model.fit(X_train_sel, y_train_res)
    preds = model.predict_proba(X_test_sel)[:, 1]
    return roc_auc_score(y_test, preds)


def optimize_extratrees(trial):
    params = {
        "n_estimators": trial.suggest_int("n_estimators", 100, 600),
        "max_depth": trial.suggest_int("max_depth", 3, 30),
        "random_state": 42
    }
    model = ExtraTreesClassifier(**params, n_jobs=-1)
    model.fit(X_train_sel, y_train_res)
    preds = model.predict_proba(X_test_sel)[:, 1]
    return roc_auc_score(y_test, preds)


def optimize_logistic(trial):
    C = trial.suggest_float("C", 1e-4, 100.0, log=True)
    model = Pipeline([
        ("scaler", StandardScaler()),
        ("lr", LogisticRegression(C=C, max_iter=5000, random_state=42))
    ])
    model.fit(X_train_sel, y_train_res)
    preds = model.predict_proba(X_test_sel)[:, 1]
    return roc_auc_score(y_test, preds)


def optimize_xgb(trial):
    params = {
        "n_estimators": trial.suggest_int("n_estimators", 100, 800),
        "max_depth": trial.suggest_int("max_depth", 3, 12),
        "learning_rate": trial.suggest_float("learning_rate", 0.01, 0.3),
        "subsample": trial.suggest_float("subsample", 0.5, 1.0),
        "colsample_bytree": trial.suggest_float("colsample_bytree", 0.4, 1.0),
        "gamma": trial.suggest_float("gamma", 0.0, 5.0),
        "eval_metric": "logloss",
        "random_state": 42
    }
    model = XGBClassifier(**params, n_jobs=-1)
    model.fit(X_train_sel, y_train_res)
    preds = model.predict_proba(X_test_sel)[:, 1]
    return roc_auc_score(y_test, preds)


def optimize_cat(trial):
    params = {
        "iterations": trial.suggest_int("iterations", 200, 1000),
        "depth": trial.suggest_int("depth", 3, 10),
        "learning_rate": trial.suggest_float("learning_rate", 0.01, 0.3),
        "random_state": 42,
        "verbose": 0
    }
    model = CatBoostClassifier(**params)
    model.fit(X_train_sel, y_train_res)
    preds = model.predict_proba(X_test_sel)[:, 1]
    return roc_auc_score(y_test, preds)


# ======================================================
# 2. Run Optuna Studies
# ======================================================
n_trials = 40

def run_search(func, name):
    print(f"\nStarting optimization for {name}...")
    optuna.logging.set_verbosity(optuna.logging.WARNING)
    study = optuna.create_study(direction="maximize")
    study.optimize(func, n_trials=n_trials, show_progress_bar=True)
    print(f"Best {name} ROC-AUC: {study.best_value:.4f}")
    print("Best Params:", study.best_params)
    return study.best_params


best_dt_params  = run_search(optimize_decisiontree, "DecisionTree")
best_rf_params  = run_search(optimize_rf, "RandomForest")
best_et_params  = run_search(optimize_extratrees, "ExtraTrees")
best_lr_params  = run_search(optimize_logistic, "LogisticRegression")
best_xgb_params = run_search(optimize_xgb, "XGBoost")
best_cat_params = run_search(optimize_cat, "CatBoost")


# ======================================================
# 3. Train final models
# ======================================================
final_models = {}

final_models["DecisionTree"] = DecisionTreeClassifier(
    **best_dt_params, random_state=42
).fit(X_train_sel, y_train_res)

final_models["RandomForest"] = RandomForestClassifier(
    **best_rf_params, random_state=42, n_jobs=-1
).fit(X_train_sel, y_train_res)

final_models["ExtraTrees"] = ExtraTreesClassifier(
    **best_et_params, random_state=42, n_jobs=-1
).fit(X_train_sel, y_train_res)

final_models["LogisticRegression"] = Pipeline([
    ("scaler", StandardScaler()),
    ("lr", LogisticRegression(C=best_lr_params["C"], max_iter=5000, random_state=42))
]).fit(X_train_sel, y_train_res)

final_models["XGBoost"] = XGBClassifier(
    **best_xgb_params, eval_metric="logloss", random_state=42, n_jobs=-1
).fit(X_train_sel, y_train_res)

cat_params = best_cat_params.copy()
cat_params.update({"random_state": 42, "verbose": 0})
final_models["CatBoost"] = CatBoostClassifier(**cat_params).fit(X_train_sel, y_train_res)


# ======================================================
# 4. Evaluate models + ROC curves
# ======================================================
results = []
plt.figure(figsize=(10, 8))

for name, model in final_models.items():
    res = evaluate_model(name, model, X_test_sel, y_test)
    results.append(res)
    fpr, tpr, _ = roc_curve(y_test, res["probs"])
    plt.plot(fpr, tpr, label=f"{name} (AUC={res['roc_auc']:.3f})")

plt.plot([0, 1], [0, 1], "k--", label="Random")
plt.title("ROC Curves", fontsize=14, fontweight="bold")
plt.xlabel("False Positive Rate", fontsize=12)
plt.ylabel("True Positive Rate", fontsize=12)
plt.legend(loc="lower right")
plt.grid(True, linestyle="--", alpha=0.6)
plt.tight_layout()
plt.show()


# ======================================================
# 5. Summary table + Top 2 confusion matrices + CIs
# ======================================================

# Augment results with bootstrap CIs
for r in results:
    y_true_test = y_test
    y_pred_proba_test = r["probs"]

    r["roc_auc_ci"]     = bootstrap_metric_ci(y_true_test, y_pred_proba_test, "roc_auc")
    r["pr_auc_ci"]      = bootstrap_metric_ci(y_true_test, y_pred_proba_test, "pr_auc")
    r["accuracy_ci"]    = bootstrap_metric_ci(y_true_test, y_pred_proba_test, "accuracy")
    r["precision_ci"]   = bootstrap_metric_ci(y_true_test, y_pred_proba_test, "precision")
    r["recall_ci"]      = bootstrap_metric_ci(y_true_test, y_pred_proba_test, "recall")
    r["specificity_ci"] = bootstrap_metric_ci(y_true_test, y_pred_proba_test, "specificity")
    r["f1_ci"]          = bootstrap_metric_ci(y_true_test, y_pred_proba_test, "f1")

# Create temporary DataFrame for sorting
summary_temp = pd.DataFrame([{
    "Model": r["model"],
    "ROC_AUC_val": r["roc_auc"],
    "ROC_AUC_ci": r["roc_auc_ci"],
    "PR_AUC_val": r["pr_auc"],
    "PR_AUC_ci": r["pr_auc_ci"],
    "Accuracy_val": r["accuracy"],
    "Accuracy_ci": r["accuracy_ci"],
    "Precision_val": r["precision"],
    "Precision_ci": r["precision_ci"],
    "Recall_val": r["recall"],
    "Recall_ci": r["recall_ci"],
    "Specificity_val": r["specificity"],
    "Specificity_ci": r["specificity_ci"],
    "F1_val": r["f1"],
    "F1_ci": r["f1_ci"]
} for r in results]).sort_values("ROC_AUC_val", ascending=False).reset_index(drop=True)

# Format final summary table with CI ranges
summary_formatted_data = []
for idx, row in summary_temp.iterrows():
    formatted_row = {
        "Model": row["Model"],
        "ROC_AUC": f"{row['ROC_AUC_val']:.3f} ({row['ROC_AUC_ci'][0]:.3f}-{row['ROC_AUC_ci'][1]:.3f})",
        "PR_AUC": f"{row['PR_AUC_val']:.3f} ({row['PR_AUC_ci'][0]:.3f}-{row['PR_AUC_ci'][1]:.3f})",
        "Accuracy": f"{row['Accuracy_val']:.3f} ({row['Accuracy_ci'][0]:.3f}-{row['Accuracy_ci'][1]:.3f})",
        "Precision": f"{row['Precision_val']:.3f} ({row['Precision_ci'][0]:.3f}-{row['Precision_ci'][1]:.3f})",
        "Recall": f"{row['Recall_val']:.3f} ({row['Recall_ci'][0]:.3f}-{row['Recall_ci'][1]:.3f})",
        "Specificity": f"{row['Specificity_val']:.3f} ({row['Specificity_ci'][0]:.3f}-{row['Specificity_ci'][1]:.3f})",
        "F1": f"{row['F1_val']:.3f} ({row['F1_ci'][0]:.3f}-{row['F1_ci'][1]:.3f})"
    }
    summary_formatted_data.append(formatted_row)

summary = pd.DataFrame(summary_formatted_data)

print("\nModel Performance Summary (with 95% CI):")
print(summary.to_string())

top_models = summary_temp["Model"].head(2).tolist()

for tm in top_models:
    print(f"\n--- {tm} ---")
    model_obj = final_models[tm]
    try:
        probs = model_obj.predict_proba(X_test_sel)[:, 1]
        preds = (probs >= 0.5).astype(int)
    except Exception:
        preds = model_obj.predict(X_test_sel)

    print("Confusion Matrix:\n", confusion_matrix(y_test, preds))
    print("Classification Report:\n", classification_report(y_test, preds))

# Save detailed numerical summary with lower/upper CIs to CSV
summary_numeric_for_csv = pd.DataFrame([{
    "Model": r["model"],
    "ROC_AUC": r["roc_auc"],
    "ROC_AUC_lower_ci": r["roc_auc_ci"][0],
    "ROC_AUC_upper_ci": r["roc_auc_ci"][1],
    "PR_AUC": r["pr_auc"],
    "PR_AUC_lower_ci": r["pr_auc_ci"][0],
    "PR_AUC_upper_ci": r["pr_auc_ci"][1],
    "Accuracy": r["accuracy"],
    "Accuracy_lower_ci": r["accuracy_ci"][0],
    "Accuracy_upper_ci": r["accuracy_ci"][1],
    "Precision": r["precision"],
    "Precision_lower_ci": r["precision_ci"][0],
    "Precision_upper_ci": r["precision_ci"][1],
    "Recall": r["recall"],
    "Recall_lower_ci": r["recall_ci"][0],
    "Recall_upper_ci": r["recall_ci"][1],
    "Specificity": r["specificity"],
    "Specificity_lower_ci": r["specificity_ci"][0],
    "Specificity_upper_ci": r["specificity_ci"][1],
    "F1": r["f1"],
    "F1_lower_ci": r["f1_ci"][0],
    "F1_upper_ci": r["f1_ci"][1]
} for r in results]).sort_values("ROC_AUC", ascending=False).reset_index(drop=True)

summary_numeric_for_csv.to_csv("model_performance_summary_with_ci.csv", index=False)
print("\nSaved detailed summary with numerical CIs to model_performance_summary_with_ci.csv")
# Out:
# Selected features (RFE): ['age', 'household_head_age', 'lifetime_sex_partners', 'age_first_sex', 'breast_exam', 'wealth_index', 'marital_status', 'education_level', 'ever_tested_hiv', 'mobile_phone']
#
# Starting optimization for DecisionTree...
#   0%|          | 0/40 [00:00<?, ?it/s]
# Best DecisionTree ROC-AUC: 0.7817
# Best Params: {'max_depth': 4, 'min_samples_split': 10}
#
# Starting optimization for RandomForest...
#   0%|          | 0/40 [00:00<?, ?it/s]
# Best RandomForest ROC-AUC: 0.8036
# Best Params: {'n_estimators': 364, 'max_depth': 5, 'min_samples_split': 5}
#
# Starting optimization for ExtraTrees...
#   0%|          | 0/40 [00:00<?, ?it/s]
# Best ExtraTrees ROC-AUC: 0.8038
# Best Params: {'n_estimators': 362, 'max_depth': 7}
#
# Starting optimization for LogisticRegression...
#   0%|          | 0/40 [00:00<?, ?it/s]
# Best LogisticRegression ROC-AUC: 0.8045
# Best Params: {'C': 0.0007948825061353517}
#
# Starting optimization for XGBoost...
# ...

# %%
import warnings
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
from scipy.special import logit
from sklearn.calibration import calibration_curve
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import brier_score_loss

warnings.filterwarnings("ignore")

# --- Helper: Bootstrap 95% CI for Calibration Metrics ---
def compute_calibration_metrics_with_ci(y_true, y_probs, n_bootstraps=1000, random_state=42):
    rng = np.random.default_rng(random_state)
    n_samples = len(y_true)

    # Clip probabilities to avoid -inf/inf in logit transformation
    eps = 1e-15
    y_probs_clipped = np.clip(y_probs, eps, 1 - eps)
    log_odds = logit(y_probs_clipped).reshape(-1, 1)

    # Point estimates
    brier_pt = brier_score_loss(y_true, y_probs)

    # Fit unregularized logistic regression on log-odds: logit(p) ~ a + b * logit(pred)
    lr = LogisticRegression(penalty=None, solver="lbfgs")
    try:
        lr.fit(log_odds, y_true)
        intercept_pt = lr.intercept_[0]
        slope_pt = lr.coef_[0][0]
    except Exception:
        intercept_pt, slope_pt = np.nan, np.nan

    # Bootstrap CIs
    brier_boots = []
    intercept_boots = []
    slope_boots = []

    for _ in range(n_bootstraps):
        idx = rng.choice(n_samples, size=n_samples, replace=True)
        y_t_b = y_true[idx]
        y_p_b = y_probs_clipped[idx]

        # Skip if sample contains only one class
        if len(np.unique(y_t_b)) < 2:
            continue

        brier_boots.append(brier_score_loss(y_t_b, y_p_b))

        try:
            lr_b = LogisticRegression(penalty=None, solver="lbfgs")
            lr_b.fit(logit(y_p_b).reshape(-1, 1), y_t_b)
            intercept_boots.append(lr_b.intercept_[0])
            slope_boots.append(lr_b.coef_[0][0])
        except Exception:
            continue

    # Percentile method for 95% CI
    brier_ci = np.percentile(brier_boots, [2.5, 97.5]) if brier_boots else (np.nan, np.nan)
    intercept_ci = np.percentile(intercept_boots, [2.5, 97.5]) if intercept_boots else (np.nan, np.nan)
    slope_ci = np.percentile(slope_boots, [2.5, 97.5]) if slope_boots else (np.nan, np.nan)

    return {
        "brier": brier_pt,
        "brier_ci": brier_ci,
        "intercept": intercept_pt,
        "intercept_ci": intercept_ci,
        "slope": slope_pt,
        "slope_ci": slope_ci,
    }


# Ensure y_test is a flat numpy array
y_test_arr = np.asarray(y_test)

print("\n--- Computing Model Calibration Metrics with 95% CI ---")
calibration_records = []

for r in results:
    model_name = r["model"]
    y_pred_proba = np.asarray(r["probs"])

    metrics = compute_calibration_metrics_with_ci(y_test_arr, y_pred_proba)

    calibration_records.append({
        "Model": model_name,
        "Brier Score": round(metrics["brier"], 4),
        "Brier 95% CI": f"[{metrics['brier_ci'][0]:.4f}, {metrics['brier_ci'][1]:.4f}]",
        "Cal. Intercept": round(metrics["intercept"], 4),
        "Intercept 95% CI": f"[{metrics['intercept_ci'][0]:.4f}, {metrics['intercept_ci'][1]:.4f}]",
        "Cal. Slope": round(metrics["slope"], 4),
        "Slope 95% CI": f"[{metrics['slope_ci'][0]:.4f}, {metrics['slope_ci'][1]:.4f}]",
        # Formatted string columns for clean presentation
        "Brier (95% CI)": f"{metrics['brier']:.3f} ({metrics['brier_ci'][0]:.3f}–{metrics['brier_ci'][1]:.3f})",
        "Intercept (95% CI)": f"{metrics['intercept']:.3f} ({metrics['intercept_ci'][0]:.3f}–{metrics['intercept_ci'][1]:.3f})",
        "Slope (95% CI)": f"{metrics['slope']:.3f} ({metrics['slope_ci'][0]:.3f}–{metrics['slope_ci'][1]:.3f})",
    })

# Convert to DataFrame
calibration_df = pd.DataFrame(calibration_records)

# Sort by Brier Score (lower is better)
calibration_df = calibration_df.sort_values(by="Brier Score", ascending=True).reset_index(drop=True)

# Save to CSV
csv_filename = "model_calibration_metrics.csv"
calibration_df.to_csv(csv_filename, index=False)
print(f"Results saved to {csv_filename}\n")

# Display formatted summary table
display_cols = ["Model", "Brier (95% CI)", "Intercept (95% CI)", "Slope (95% CI)"]
print(calibration_df[display_cols].to_string(index=False))


# --- Calibration Plots for All Models ---
print("\n--- Generating Calibration Plots for All Models ---")

# Option A: Single Combined Plot with All Models
plt.figure(figsize=(9, 7))
ax = plt.gca()

for r in results:
    model_name = r["model"]
    y_pred_proba = np.asarray(r["probs"])
    brier = brier_score_loss(y_test_arr, y_pred_proba)

    frac_pos, mean_pred = calibration_curve(y_test_arr, y_pred_proba, n_bins=10)
    ax.plot(mean_pred, frac_pos, "s-", label=f"{model_name} (Brier: {brier:.3f})")

ax.plot([0, 1], [0, 1], "k--", label="Perfect Calibration")
ax.set_xlabel("Mean Predicted Probability", fontsize=11)
ax.set_ylabel("Observed Fraction of Positives", fontsize=11)
ax.set_title("Calibration Plots Across Models", fontsize=13)
ax.legend(loc="lower right")
ax.grid(True, linestyle="--", alpha=0.6)
plt.tight_layout()
plt.savefig("all_models_combined_calibration_plot.png", dpi=300)
plt.show()

# Option B: Individual Subplots for Each Model
n_models = len(results)
n_cols = min(3, n_models)
n_rows = int(np.ceil(n_models / n_cols))

fig, axes = plt.subplots(n_rows, n_cols, figsize=(5 * n_cols, 4.5 * n_rows), squeeze=False)
axes_flat = axes.flatten()

for idx, r in enumerate(results):
    ax = axes_flat[idx]
    model_name = r["model"]
    y_pred_proba = np.asarray(r["probs"])
    brier = brier_score_loss(y_test_arr, y_pred_proba)

    frac_pos, mean_pred = calibration_curve(y_test_arr, y_pred_proba, n_bins=10)

    ax.plot(mean_pred, frac_pos, "s-", color="tab:blue", label=f"{model_name}\nBrier: {brier:.3f}")
    ax.plot([0, 1], [0, 1], "k--", alpha=0.7, label="Perfect")
    ax.set_xlim([0.0, 1.0])
    ax.set_ylim([0.0, 1.0])
    ax.set_xlabel("Mean Predicted Probability")
    ax.set_ylabel("Observed Proportion")
    ax.set_title(f"{model_name}")
    ax.legend(loc="lower right")
    ax.grid(True, linestyle="--", alpha=0.6)

# Hide any unused subplot axes
for idx in range(n_models, len(axes_flat)):
    fig.delaxes(axes_flat[idx])

plt.tight_layout()
plt.savefig("individual_models_calibration_plots.png", dpi=300)
plt.show()
# Out:
# --- Computing Model Calibration Metrics with 95% CI ---
# Results saved to model_calibration_metrics.csv
#
#              Model      Brier (95% CI)     Intercept (95% CI)      Slope (95% CI)
#           CatBoost 0.148 (0.141–0.155) -0.136 (-0.248–-0.020) 1.058 (0.964–1.161)
#            XGBoost 0.151 (0.144–0.157) -0.299 (-0.405–-0.193) 1.090 (0.996–1.195)
#       RandomForest 0.185 (0.179–0.191) -1.025 (-1.131–-0.927) 1.324 (1.198–1.472)
#         ExtraTrees 0.186 (0.180–0.192) -1.029 (-1.135–-0.930) 1.299 (1.159–1.452)
# LogisticRegression 0.186 (0.181–0.192) -1.059 (-1.163–-0.963) 1.436 (1.310–1.578)
#       DecisionTree 0.191 (0.184–0.198) -0.983 (-1.099–-0.882) 0.881 (0.689–1.048)
#
# --- Generating Calibration Plots for All Models ---

# %%
# ============================================================
# CATBOOST SHAP ANALYSIS
# ============================================================

import shap
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd


# ============================================================
# 1. SELECT CATBOOST MODEL
# ============================================================

best_model_name = "CatBoost"

# Retrieve the already fitted CatBoost model
best_model = final_models[best_model_name]

print("=" * 70)
print(f"SHAP ANALYSIS FOR: {best_model_name}")
print("=" * 70)


# ============================================================
# 2. ENSURE X_TEST_SEL IS A DATAFRAME
# ============================================================

if not isinstance(X_test_sel, pd.DataFrame):
    X_test_sel = pd.DataFrame(
        X_test_sel,
        columns=selected_features
    )

print(f"\nTest dataset shape: {X_test_sel.shape}")
print(f"Number of features: {X_test_sel.shape[1]}")


# ============================================================
# 3. CREATE SHAP EXPLAINER
# ============================================================

print("\nCreating SHAP TreeExplainer...")

explainer = shap.TreeExplainer(best_model)


# ============================================================
# 4. CALCULATE SHAP VALUES
# ============================================================

print("Calculating SHAP values...")

shap_values = explainer.shap_values(X_test_sel)


# ============================================================
# 5. EXTRACT POSITIVE-CLASS SHAP VALUES
# ============================================================

if isinstance(shap_values, list):

    # Older SHAP versions:
    # [class 0 SHAP values, class 1 SHAP values]
    shap_values_for_plot = shap_values[1]

elif isinstance(shap_values, np.ndarray) and shap_values.ndim == 3:

    # Newer SHAP versions:
    # samples × features × classes
    shap_values_for_plot = shap_values[:, :, 1]

else:

    # Already a 2-dimensional array
    shap_values_for_plot = shap_values


# Convert to numpy array
shap_values_for_plot = np.asarray(shap_values_for_plot)


print(
    "\nSHAP values shape:",
    shap_values_for_plot.shape
)


# ============================================================
# 6. CHECK DIMENSIONS
# ============================================================

if shap_values_for_plot.shape[1] != X_test_sel.shape[1]:

    raise ValueError(
        f"Mismatch between SHAP values "
        f"({shap_values_for_plot.shape[1]} features) "
        f"and X_test_sel "
        f"({X_test_sel.shape[1]} features)."
    )


# ============================================================
# 7. CALCULATE MEAN ABSOLUTE SHAP VALUES
# ============================================================

mean_abs_shap = np.abs(
    shap_values_for_plot
).mean(axis=0)


# ============================================================
# 8. CREATE SHAP IMPORTANCE DATAFRAME
# ============================================================

shap_importance = pd.DataFrame({

    "Feature": X_test_sel.columns,

    "Mean_Absolute_SHAP": mean_abs_shap

})


# Sort from lowest to highest
# This makes the highest feature appear at the top
shap_importance = shap_importance.sort_values(
    "Mean_Absolute_SHAP",
    ascending=True
)


# Display SHAP importance table
print("\n" + "=" * 70)
print("SHAP FEATURE IMPORTANCE")
print("=" * 70)

print(
    shap_importance
    .sort_values(
        "Mean_Absolute_SHAP",
        ascending=False
    )
    .to_string(index=False)
)


# ============================================================
# 9. SHAP BAR PLOT WITH VALUES ON BARS
# ============================================================

print("\nGenerating SHAP bar plot...")


fig, ax = plt.subplots(
    figsize=(11, 8)
)


bars = ax.barh(

    shap_importance["Feature"],

    shap_importance["Mean_Absolute_SHAP"]

)


# ------------------------------------------------------------
# Add numerical SHAP values at the end of each bar
# ------------------------------------------------------------

max_shap = shap_importance[
    "Mean_Absolute_SHAP"
].max()


for bar, value in zip(
    bars,
    shap_importance["Mean_Absolute_SHAP"]
):

    ax.text(

        bar.get_width()
        + (max_shap * 0.01),

        bar.get_y()
        + bar.get_height() / 2,

        f"{value:.4f}",

        va="center",

        fontsize=9

    )


# ------------------------------------------------------------
# Axis labels and title
# ------------------------------------------------------------

ax.set_xlabel(
    "Mean Absolute SHAP Value",
    fontsize=11
)

ax.set_ylabel(
    "Features",
    fontsize=11
)

ax.set_title(
    "SHAP Feature Importance for CatBoost",
    fontsize=14,
    fontweight="bold"
)


# ------------------------------------------------------------
# Clean appearance
# ------------------------------------------------------------

ax.spines["top"].set_visible(False)
ax.spines["right"].set_visible(False)


# Add a little space on the right for the numbers
ax.set_xlim(
    0,
    max_shap * 1.15
)


plt.tight_layout()
plt.show()


# ============================================================
# 10. SHAP BEESWARM SUMMARY PLOT
# ============================================================

print("\nGenerating SHAP beeswarm summary plot...")


plt.figure(
    figsize=(11, 8)
)


shap.summary_plot(

    shap_values_for_plot,

    X_test_sel,

    show=False

)


plt.title(
    "SHAP Summary Plot for CatBoost",
    fontsize=14,
    fontweight="bold"
)


plt.tight_layout()
plt.show()


# ============================================================
# 11. SHAP WATERFALL PLOT
# ============================================================

print("\nGenerating SHAP waterfall plot...")


# Select one observation from the test set
instance_index = 0


# Extract observation
instance_data = X_test_sel.iloc[
    instance_index
]


# Extract SHAP values for this observation
instance_shap_values = (
    shap_values_for_plot[
        instance_index
    ]
)


# ============================================================
# 12. DETERMINE BASE VALUE
# ============================================================

expected_value = explainer.expected_value


if isinstance(
    expected_value,
    (list, np.ndarray)
):

    expected_value = np.asarray(
        expected_value
    )

    if expected_value.ndim > 0:

        if expected_value.size > 1:

            # Positive class
            expected_value = expected_value[1]

        else:

            expected_value = expected_value.item()


# Convert to scalar
expected_value = float(
    np.asarray(
        expected_value
    ).reshape(-1)[0]
)


# ============================================================
# 13. CREATE SHAP EXPLANATION OBJECT
# ============================================================

shap_explanation = shap.Explanation(

    values=instance_shap_values,

    base_values=expected_value,

    data=instance_data.values,

    feature_names=X_test_sel.columns.tolist()

)


# ============================================================
# 14. WATERFALL PLOT
# ============================================================

shap.plots.waterfall(

    shap_explanation,

    max_display=15,

    show=False

)


plt.title(

    f"SHAP Waterfall Plot for "
    f"CatBoost (Test Instance {instance_index})",

    fontsize=14,

    fontweight="bold"

)


plt.tight_layout()
plt.show()


# ============================================================
# 15. SAVE SHAP IMPORTANCE TABLE
# ============================================================

shap_importance_output = (
    shap_importance
    .sort_values(
        "Mean_Absolute_SHAP",
        ascending=False
    )
    .reset_index(drop=True)
)


print("\n" + "=" * 70)
print("FINAL SHAP RANKING")
print("=" * 70)

print(
    shap_importance_output.to_string(
        index=False
    )
)


# ============================================================
# END OF SHAP ANALYSIS
# ============================================================
# Out:
# ...
# SHAP ANALYSIS FOR: CatBoost
# ...
#
# Test dataset shape: (2782, 10)
# Number of features: 10
#
# Creating SHAP TreeExplainer...
# Calculating SHAP values...
#
# SHAP values shape: (2782, 10)
#
# ...
# SHAP FEATURE IMPORTANCE
# ...
#               Feature  Mean_Absolute_SHAP
#                   age            0.657458
#    household_head_age            0.524154
#           breast_exam            0.446145
#       ever_tested_hiv            0.404262
# lifetime_sex_partners            0.250105
#          mobile_phone            0.202113
#          wealth_index            0.186049
#        marital_status            0.109517
#       education_level            0.079926
#         age_first_sex            0.059334
#
# Generating SHAP bar plot...
# Generating SHAP beeswarm summary plot...
# Generating SHAP waterfall plot...
# ...
# FINAL SHAP RANKING
# ...
#               Feature  Mean_Absolute_SHAP
#                   age            0.657458
#    household_head_age            0.524154
# ...
